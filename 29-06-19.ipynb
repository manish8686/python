# %%
#create a series by passing a list of values
import pandas as pd
a= pd.Series([1,3,4,5,6,7])
print(a)
# Out:
# 0    1
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# dtype: int64

# %%
# missingvalues then it can be nan of numpy
import numpy as np
a1=pd.Series([1,2,3,4,np.nan,6])
print(a1)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    NaN
# 5    6.0
# dtype: float64

# %%
# create a list of dates with in particular range
dates=pd.date_range('20190601',periods=10)
print(dates)
# Out:
# DatetimeIndex(['2019-06-01', '2019-06-02', '2019-06-03', '2019-06-04',
#                '2019-06-05', '2019-06-06', '2019-06-07', '2019-06-08',
#                '2019-06-09', '2019-06-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
lst=pd.date_range('20190601',periods=5)
print(lst)
# Out:
# DatetimeIndex(['2019-06-01', '2019-06-02', '2019-06-03', '2019-06-04',
#                '2019-06-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
a2=pd.DataFrame(np.random.rand(6,4),index=dates,columns=list('abcd'))
print(a2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1652
# -> 1653         mgr = BlockManager(blocks, axes)
#    1654         mgr._consolidate_inplace()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in __init__(self, blocks, axes, do_integrity_check)
#     113         if do_integrity_check:
# --> 114             self._verify_integrity()
#     115
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in _verify_integrity(self)
#     310             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# --> 311                 construction_error(tot_items, block.shape[1:], self.axes)
#     312         if len(self.items) != tot_items:
#
# ...

# %%
a3=pd.DataFrame({'A':1.,
                'B':pd.Timestamp('20190601'),
                'C':pd.Series(1,index=list(range(4)),dtype='float32'),
                'D':np.array([3]*4,dtype='int32'),
                'E':pd.Categorical(["test","train","test","train"]),
                'F':'foo'})
print(a3)
# Out:
#      A          B    C  D      E    F
# 0  1.0 2019-06-01  1.0  3   test  foo
# 1  1.0 2019-06-01  1.0  3  train  foo
# 2  1.0 2019-06-01  1.0  3   test  foo
# 3  1.0 2019-06-01  1.0  3  train  foo

# %%
#Turtle is a python feature like a drawing board
#lines,squares,star,,rect and etc
#
import turtle as tt
a1=tt.Turtle
tt.foward(100)
tt.done()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-109c76131340> in <module>()
#       1 import turtle as tt
#       2 a1=tt.Turtle
# ----> 3 tt.foward(100)
#       4 tt.done()
#
# AttributeError: module 'turtle' has no attribute 'foward'

# %%
import turtle as tt
a1=tt.Turtle()
a1.forward(150)
a1.right(90)

a1.forward(150)
a1.right(90)

a1.forward(150)
a1.right(90)

a1.forward(150)
a1.right(90)

tt.done
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-18-431736fd5e07> in <module>()
#       1 import turtle as tt
# ----> 2 a1=tt.Turtle()
#       3 a1.forward(150)
#       4 a1.right(90)
#       5
#
# /usr/lib/python3.6/turtle.py in __init__(self, shape, undobuffersize, visible)
#    3810                  visible=_CFG["visible"]):
#    3811         if Turtle._screen is None:
# -> 3812             Turtle._screen = Screen()
#    3813         RawTurtle.__init__(self, Turtle._screen,
#    3814                            shape=shape,
#
# /usr/lib/python3.6/turtle.py in Screen()
#    3660     else return the existing one."""
#    3661     if Turtle._screen is None:
# -> 3662         Turtle._screen = _Screen()
#    3663     return Turtle._screen
#    3664
#
# /usr/lib/python3.6/turtle.py in __init__(self)
# ...

# %%
import turtle as tt
a1 = tt.Turtle()
for x in range (40):
    a1.forward(50)
    a1.right(144)
tt.done
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-19-5fadb1678b8b> in <module>()
#       1 import turtle as tt
# ----> 2 a1 = tt.Turtle()
#       3 for x in range (40):
#       4     a1.forward(50)
#       5     a1.right(144)
#
# /usr/lib/python3.6/turtle.py in __init__(self, shape, undobuffersize, visible)
#    3810                  visible=_CFG["visible"]):
#    3811         if Turtle._screen is None:
# -> 3812             Turtle._screen = Screen()
#    3813         RawTurtle.__init__(self, Turtle._screen,
#    3814                            shape=shape,
#
# /usr/lib/python3.6/turtle.py in Screen()
#    3660     else return the existing one."""
#    3661     if Turtle._screen is None:
# -> 3662         Turtle._screen = _Screen()
#    3663     return Turtle._screen
#    3664
#
# /usr/lib/python3.6/turtle.py in __init__(self)
# ...

# %%
#spirating
import turtle as tt
a1=tt.Turtle()
for i in range(40)
    a1.forward(i*10)
    a1.right(144)
tt.done()
# Out:
#   File "<ipython-input-20-027612b8929a>", line 3
#     for i in range(20)
#                       ^
# SyntaxError: invalid syntax

# %%
import turtlt as tt

c1=tt.Turtle()
c1.pencolor("blue")
for i in range(50):
    c1.forward(50)
    c1.left(123)
    
c1.pencolor("red")
for i in range(50):
    c1.forward(50)
    c1.left(123)
    
tt.done()

# %%
import turtle as tt

colors=['red','blue','orange','green','yellow','purple']

a1=tt.Turtle()

for x in range(360):
    a1.pencolor(colors[x%6])
    a1.width(x/100+1)
    a1.forward(x)
    a1.left(59)
    
tt.done()

# %%
import turtle as tt
a1 = tt.Turtle()

colors=['red','blue','orange','green','yellow','purple']
dot_distance=10
width=10
height=15

a1.penup()

for x in range(height):
    a1.pencolor(colors[x%6])
    for i in range(width):
      a1.dot()
      a1.forward(dot_distance)
  a1.forward(dot_distance * width)
  a1.right(90)
  a1.forward(dot_distance * width)
  a1.left(90)

tt.done()

# %%
#generating bule in flowers
from turtle import *
import random

for n in range(50):
    penup()
    goto(random.randint(-400,400),random.randint(-400,400))
    pendown()
    
    red_amount = random.randint(0,30)/100.0
    blue_amount = random.randint(50,100)/100.0
    green_amount = random.randint(0,30)/100.0
    
    pencolor((red_amount,blue_amount,green_amount))
    
    circle_size = random.randint(10,40)
    pensize(random.randint(4,6))
    
    for i in range(6):
        circle(circle_size)
        left(60)

# %%
from turtle import *

def main():
    colors=("red","orange","yellow","seagreen4","orchid4","royalblue1","dodgerblue2")
    reset()
    screen()
    up()
    goto(-320,-195)
    width(70)
    for pcolor in colors:
        color(pcolor)
        down()
        forward(640)
        up()
        backward(640)
        left(90)
        forward(66)
        right(90)
        
    width(55)
    color("white")
    goto(0,-170)
    down()
    
    circle(170)
    left(90)
    forward(340)
    up()
    left(180)
    forward(170)
    right(45)
    down()
    forward(170)
    up()
    backward(170)
    left(90)
    down()
    forward(170)
    up()
    goto(0,300)
    
if __name__=="__main__":
    main()
    mainloop()
